# %% [markdown]
# # 00 - Environment Check
# Verify all dependencies and paths are correctly configured.

# %%
import sys
import os
print(f"Python: {sys.version}")

# Add project root to path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Python: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# Project root: D:\MyJupyter\Works\3DPART

# %%
# Check dependencies
deps = {
    'numpy': 'numpy',
    'scipy': 'scipy',
    'trimesh': 'trimesh',
    'open3d': 'open3d',
    'matplotlib': 'matplotlib',
    'yaml': 'pyyaml',
    'pandas': 'pandas',
    'tqdm': 'tqdm',
    'sklearn': 'scikit-learn',
    'PIL': 'Pillow',
    'tabulate': 'tabulate',
    'seaborn': 'seaborn',
}

for module, pkg in deps.items():
    try:
        m = __import__(module)
        ver = getattr(m, '__version__', 'OK')
        print(f"  [OK] {pkg:20s} {ver}")
    except ImportError:
        print(f"  [MISSING] {pkg:20s}  --> pip install {pkg}")
# Out:
#   [OK] numpy                2.2.5
#   [OK] scipy                1.15.3
#   [OK] trimesh              4.11.5
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
#   [OK] open3d               0.19.0
#   [OK] matplotlib           3.10.8
#   [OK] pyyaml               6.0.3
#   [OK] pandas               2.3.3
#   [OK] tqdm                 4.67.3
#   [OK] scikit-learn         1.7.2
#   [OK] Pillow               12.0.0
#   [OK] tabulate             0.10.0
#   [OK] seaborn              0.13.2

# %%
# Check project modules
from src.config import load_config, ensure_dirs
from src.io import load_mesh, save_mesh
from src.geometry import extract_boundary_loops
from src.target_selection import select_target_loops_by_bbox
from src.repair import center_fan_repair, planar_triangulation_repair
from src.evaluation import Evaluator
print("\n All project modules loaded successfully!")
# Out:
#  All project modules loaded successfully!

# %%
# Load and check config
cfg = load_config(os.path.join(PROJECT_ROOT, 'configs', 'chair_leg.yaml'))
print(f"PartNet root: {cfg['paths']['partnet_root']}")
print(f"Category: {cfg['dataset']['category']}")
print(f"Semantic label: {cfg['dataset']['semantic_label']}")
print(f"Total samples: {cfg['dataset']['total_samples']}")

# Check PartNet directory
partnet_root = cfg['paths']['partnet_root']
if os.path.exists(partnet_root):
    n_dirs = len([d for d in os.listdir(partnet_root) if os.path.isdir(os.path.join(partnet_root, d))])
    print(f"\nPartNet directory found: {n_dirs} subdirectories")
else:
    print(f"\n WARNING: PartNet directory not found at {partnet_root}")
    print("  Please update configs/default.yaml with the correct path")
# Out:
# PartNet root: E:/datasets/partnet
# Category: Chair
# Semantic label: leg
# Total samples: 100
#
# PartNet directory found: 32537 subdirectories

# %%
# Create output directories
ensure_dirs(cfg)
print("Output directories created.")
# Out:
# Output directories created.
